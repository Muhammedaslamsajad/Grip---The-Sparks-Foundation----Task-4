# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("C:\\Users\\hp\\Downloads\\GlobalTerrorism.csv")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
for col in data.columns:
    if (data[col].isnull().sum()/len(data.index)*100)>  45:
        data.drop(col,axis=1,inplace=True)

# %%
data.shape
# Out:
# (181691, 58)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  extended  country  \
# 0       197000000001   1970       7     2         0       58
# 1       197000000002   1970       0     0         0      130
# 2       197001000001   1970       1     0         0      160
# 3       197001000002   1970       1     0         0       78
# 4       197001000003   1970       1     0         0      101
# ...              ...    ...     ...   ...       ...      ...
# 181686  201712310022   2017      12    31         0      182
# 181687  201712310029   2017      12    31         0      200
# 181688  201712310030   2017      12    31         0      160
# 181689  201712310031   2017      12    31         0       92
# 181690  201712310032   2017      12    31         0      160
#
#                country_txt  region                   region_txt  \
# 0       Dominican Republic       2  Central America & Caribbean
# 1                   Mexico       1                North America
# ...

# %%
#dropping 
data=data.drop(['extended'],1)

# %%
data.shape
# Out:
# (181691, 57)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nwoundus'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nwound'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nwoundte'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nkillus'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nkillter'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['ishostkid'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
#dropping 
data=data.drop(['nkill'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
data.shape
# Out:
# (181691, 50)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country', 'country_txt',
#        'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude',
#        'specificity', 'vicinity', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1',
#        'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt',
#        'gname', 'guncertain1', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'weaptype1', 'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt',
#        'weapdetail', 'property', 'scite1', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
data["region"].value_counts(dropna= False,normalize=True)
# Out:
# 10    0.277801
# 6     0.247530
# 3     0.104452
# 11    0.096593
# 8     0.091579
# 5     0.068716
# 2     0.056932
# 9     0.028312
# 1     0.019021
# 4     0.004414
# 7     0.003099
# 12    0.001552
# Name: region, dtype: float64

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.attacktype1)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.attacktype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.targtype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.targsubtype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.natlty1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.weapsubtype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.weaptype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
